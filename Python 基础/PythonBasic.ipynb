# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#安装-Python" data-toc-modified-id="安装-Python-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>安装 Python</a></span></li><li><span><a href="#1.-变量和类型" data-toc-modified-id="1.-变量和类型-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>1. 变量和类型</a></span><ul class="toc-item"><li><span><a href="#变量赋值" data-toc-modified-id="变量赋值-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>变量赋值</a></span></li><li><span><a href="#运算" data-toc-modified-id="运算-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>运算</a></span></li><li><span><a href="#类型与类型转换" data-toc-modified-id="类型与类型转换-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>类型与类型转换</a></span></li></ul></li><li><span><a href="#2.-字符串（String）" data-toc-modified-id="2.-字符串（String）-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>2. 字符串（String）</a></span><ul class="toc-item"><li><span><a href="#帮助" data-toc-modified-id="帮助-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>帮助</a></span></li><li><span><a href="#字符串操作" data-toc-modified-id="字符串操作-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>字符串操作</a></span></li><li><span><a href="#字符串方法" data-toc-modified-id="字符串方法-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>字符串方法</a></span></li></ul></li><li><span><a href="#3.-列表（List）" data-toc-modified-id="3.-列表（List）-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>3. 列表（List）</a></span><ul class="toc-item"><li><span><a href="#元素选择" data-toc-modified-id="元素选择-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>元素选择</a></span></li></ul></li><li><span><a href="#4.-库" data-toc-modified-id="4.-库-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>4. 库</a></span><ul class="toc-item"><li><span><a href="#导入库" data-toc-modified-id="导入库-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>导入库</a></span></li><li><span><a href="#选择性导入" data-toc-modified-id="选择性导入-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>选择性导入</a></span></li></ul></li><li><span><a href="#5.-Numpy-数组" data-toc-modified-id="5.-Numpy-数组-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>5. Numpy 数组</a></span><ul class="toc-item"><li><span><a href="#Numpy-数组元素选择" data-toc-modified-id="Numpy-数组元素选择-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Numpy 数组元素选择</a></span></li><li><span><a href="#Numpy-数组操作" data-toc-modified-id="Numpy-数组操作-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Numpy 数组操作</a></span></li><li><span><a href="#Numpy-数组函数" data-toc-modified-id="Numpy-数组函数-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Numpy 数组函数</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## 安装 Python

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [https://www.anaconda.com/](https://www.anaconda.com/)
#
# 由 Python 提供支持的领先开放数据科学平台

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [https://www.spyder-ide.org/](https://www.spyder-ide.org/)
#
# Anaconda 附带的免费 IDE

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [https://jupyter.org/](https://jupyter.org/)
#
# 使用实时代码，可视化，文本创建和共享文档……

# %% [markdown]
# ## 1. 变量和类型

# %% [markdown]
# ### 变量赋值

# %%
x = 5
x
# Out:
# 5

# %% [markdown]
# ### 运算

# %%
x + 9 # 加
# Out:
# 14

# %%
x - 9 # 减
# Out:
# -4

# %%
x * 9 # 乘
# Out:
# 45

# %%
x ** 9 # 乘方
# Out:
# 1953125

# %%
x % 9 # 取模
# Out:
# 5

# %%
x / float(9) # 除
# Out:
# 0.5555555555555556

# %% [markdown]
# ### 类型与类型转换

# %% [markdown]
# | 类型转换 | 示例 | 类型 |
# | - | - | - |
# | str() | '59', '3.14', 'True' |  字符串 |
# | int() | 5, 9 | 整型 |
# | float() | 5.9, 3.14 | 浮点数 |
# | bool() | True, True, True | 布尔 |

# %% [markdown]
# ## 2. 字符串（String）

# %% [markdown]
# ### 帮助

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
zh_string = "最好的人工智能开发"
zh_string
# Out:
# '最好的人工智能开发'

# %% [markdown]
# ### 字符串操作

# %%
zh_string * 2
# Out:
# '最好的人工智能开发最好的人工智能开发'

# %%
zh_string + '就在这里了'
# Out:
# '最好的人工智能开发就在这里了'

# %%
'我' in zh_string
# Out:
# False

# %% [markdown]
# ### 字符串方法

# %%
zh_string.upper()
zh_string.lower()
zh_string.count('在')
zh_string.replace('在', ' is ')
zh_string.strip()
# Out:
# '最好的人工智能开发'

# %% [markdown]
# ## 3. 列表（List）

# %%
a = '是'
b = '这'
zh_list = ['我', '列表', a, b]
zh_list2 = [[1, 3, 5, 7], [2, 4, 6, 8]]

# %% [markdown]
# ### 元素选择

# %%
# 下标
zh_list[1] # 索引从 0 开始，这里取第 2 个元素
zh_list[-1] # 最后一个元素
# Out:
# '这'

# %%
# 分片
zh_list[1:3]  # 索引 1, 2
zh_list[1:]  # 索引 1 及之后
zh_list[:3]  # 索引 3 之前
zh_list[:]  # 所有 / 复制列表
# Out:
# ['我', '列表', '是', '这']

# %%
# 子列表
zh_list + zh_list
zh_list * 2
# Out:
# ['我', '列表', '是', '这', '我', '列表', '是', '这']

# %%
# 列表方法
zh_list = [1, 3, 5, 7]
zh_list.index(3)  # 获取元素下标
zh_list.count(3)  # 统计元素个数
zh_list.append(0)  # 追加元素
zh_list.remove(0)  # 移除元素
del(zh_list[:2])  # 删除前 2 个元素
zh_list.reverse()  # 反转列表
zh_list.extend([2, 4, 6])  # 扩展列表
zh_list.pop(-1)  # 弹出（移除并返回）指定 index 元素
zh_list.insert(3, 9)  # 在 index 位置新增元素
zh_list.sort()  # 排序列表

# %% [markdown]
# ## 4. 库

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 导入库

# %%
import numpy
import numpy as np

# %% [markdown]
# ### 选择性导入

# %%
from sklearn import datasets

# %% [markdown]
# ## 5. Numpy 数组

# %%
zh_list = [1, 3, 5, 7]
zh_array = np.array(zh_list)
zh_2darray = np.array([
    [1, 3, 5, 7],
    [2, 4, 6, 8]])

# %% [markdown]
# ### Numpy 数组元素选择

# %%
# 下标
zh_list[0] # 索引从 0 开始
# Out:
# 1

# %%
# 切片
zh_list[:2]
# Out:
# [1, 3]

# %%
# 2 维数组下标
zh_2darray[:, 1]
# Out:
# array([3, 4])

# %% [markdown]
# ### Numpy 数组操作

# %%
zh_array > 3
# Out:
# array([False, False,  True,  True])

# %%
zh_array * 2
# Out:
# array([ 2,  6, 10, 14])

# %%
zh_array + np.array([9, 8, 7, 6])
# Out:
# array([10, 11, 12, 13])

# %% [markdown]
# ### Numpy 数组函数

# %%
other_array = np.array([5, 5, 5, 5])
zh_array.shape  # 维数
np.append(zh_array, other_array)  # 追加数组
np.insert(zh_array, 1, 5)  # 插入元素
np.delete(zh_array, [1])  # 删除元素
np.mean(zh_array)  # 均值
np.median(zh_array)  # 中位数
np.corrcoef(zh_array)  # 相关系数
np.std(zh_array)  # 标准差
# Out:
# 2.23606797749979
