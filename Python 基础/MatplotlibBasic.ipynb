# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#绘图解剖（Plot-Anatomy）" data-toc-modified-id="绘图解剖（Plot-Anatomy）-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>绘图解剖（Plot Anatomy）</a></span></li><li><span><a href="#工作流程（Workflow）" data-toc-modified-id="工作流程（Workflow）-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>工作流程（Workflow）</a></span></li><li><span><a href="#准备数据" data-toc-modified-id="准备数据-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>准备数据</a></span><ul class="toc-item"><li><span><a href="#1D数据" data-toc-modified-id="1D数据-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>1D数据</a></span></li><li><span><a href="#2D数据-或-图像" data-toc-modified-id="2D数据-或-图像-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>2D数据 或 图像</a></span></li></ul></li><li><span><a href="#创建图" data-toc-modified-id="创建图-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>创建图</a></span><ul class="toc-item"><li><span><a href="#图形（Figure）" data-toc-modified-id="图形（Figure）-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>图形（Figure）</a></span></li><li><span><a href="#轴（Axes）" data-toc-modified-id="轴（Axes）-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>轴（Axes）</a></span></li></ul></li><li><span><a href="#常规绘制" data-toc-modified-id="常规绘制-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>常规绘制</a></span><ul class="toc-item"><li><span><a href="#1D-数据" data-toc-modified-id="1D-数据-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>1D 数据</a></span></li><li><span><a href="#2D数据-或-图像" data-toc-modified-id="2D数据-或-图像-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>2D数据 或 图像</a></span></li><li><span><a href="#向量字段" data-toc-modified-id="向量字段-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>向量字段</a></span></li><li><span><a href="#数据分布" data-toc-modified-id="数据分布-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>数据分布</a></span></li></ul></li><li><span><a href="#自定义绘图" data-toc-modified-id="自定义绘图-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>自定义绘图</a></span><ul class="toc-item"><li><span><a href="#颜色，彩条（Color-bars）和彩图（Color-maps）" data-toc-modified-id="颜色，彩条（Color-bars）和彩图（Color-maps）-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>颜色，彩条（Color bars）和彩图（Color maps）</a></span></li><li><span><a href="#标记" data-toc-modified-id="标记-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>标记</a></span></li><li><span><a href="#线条样式" data-toc-modified-id="线条样式-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>线条样式</a></span></li><li><span><a href="#文字-&amp;-注释" data-toc-modified-id="文字-&amp;-注释-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>文字 &amp; 注释</a></span></li><li><span><a href="#数学" data-toc-modified-id="数学-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>数学</a></span></li><li><span><a href="#限制，图例-&amp;-布局（Limits,-Legends-&amp;-Layouts）" data-toc-modified-id="限制，图例-&amp;-布局（Limits,-Legends-&amp;-Layouts）-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>限制，图例 &amp; 布局（Limits, Legends &amp; Layouts）</a></span><ul class="toc-item"><li><span><a href="#限制-&amp;-自动缩放（Limits-&amp;-Autoscaling）" data-toc-modified-id="限制-&amp;-自动缩放（Limits-&amp;-Autoscaling）-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>限制 &amp; 自动缩放（Limits &amp; Autoscaling）</a></span></li><li><span><a href="#图例" data-toc-modified-id="图例-6.6.2"><span class="toc-item-num">6.6.2&nbsp;&nbsp;</span>图例</a></span></li><li><span><a href="#刻度（Ticks）" data-toc-modified-id="刻度（Ticks）-6.6.3"><span class="toc-item-num">6.6.3&nbsp;&nbsp;</span>刻度（Ticks）</a></span></li><li><span><a href="#子图间距" data-toc-modified-id="子图间距-6.6.4"><span class="toc-item-num">6.6.4&nbsp;&nbsp;</span>子图间距</a></span></li><li><span><a href="#坐标轴（Axis-Spines）" data-toc-modified-id="坐标轴（Axis-Spines）-6.6.5"><span class="toc-item-num">6.6.5&nbsp;&nbsp;</span>坐标轴（Axis Spines）</a></span></li></ul></li></ul></li><li><span><a href="#保存图" data-toc-modified-id="保存图-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>保存图</a></span><ul class="toc-item"><li><span><a href="#保存图片（Save-figures）" data-toc-modified-id="保存图片（Save-figures）-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>保存图片（Save figures）</a></span></li><li><span><a href="#保存透明图（Save-transparent-figures）" data-toc-modified-id="保存透明图（Save-transparent-figures）-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>保存透明图（Save transparent figures）</a></span></li></ul></li><li><span><a href="#显示图" data-toc-modified-id="显示图-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>显示图</a></span><ul class="toc-item"><li><span><a href="#关闭-&amp;-清除" data-toc-modified-id="关闭-&amp;-清除-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>关闭 &amp; 清除</a></span></li></ul></li><li><span><a href="#示例" data-toc-modified-id="示例-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>示例</a></span><ul class="toc-item"><li><span><a href="#折线图（Line-plot）" data-toc-modified-id="折线图（Line-plot）-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>折线图（Line plot）</a></span></li><li><span><a href="#直方图（-Histogram）" data-toc-modified-id="直方图（-Histogram）-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>直方图（ Histogram）</a></span></li><li><span><a href="#散点图（Scatter-plot）" data-toc-modified-id="散点图（Scatter-plot）-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>散点图（Scatter plot）</a></span></li><li><span><a href="#3D-图（3D-plot）" data-toc-modified-id="3D-图（3D-plot）-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>3D 图（3D plot）</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![Matplotlib](https://matplotlib.org/_static/logo2.png)

# %% [markdown]
# Matplotlib 是一个 Python 绘图库，可以跨平台生成各种硬拷贝格式和交互式环境的出版品质数据。

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Mpl_screenshot_figures_and_code.png/600px-Mpl_screenshot_figures_and_code.png)

# %% [markdown]
# ## 绘图解剖（Plot Anatomy）

# %% [markdown]
# ![Matplotlib](https://user-gold-cdn.xitu.io/2019/5/26/16af39b82c3cc2b2?w=1504&h=1366&f=png&s=312516)

# %% [markdown]
# ## 工作流程（Workflow）

# %% [markdown]
# 使用 matplotlib 创建绘图的基本步骤

# %%
import matplotlib.pyplot as plt
# 1. 准备数据
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
# 2. 创建绘图
fig = plt.figure()
# 3. 绘图
ax = fig.add_subplot(111)
# 4. 自定义绘图
ax.plot(x, y, color='lightblue', linewidth=3)
ax.scatter([2, 4, 6],
           [5, 15, 25],
           color='darkgreen',
           marker='^')
ax.set_xlim(1, 6.5)
# 5. 保存图
plt.savefig('foo.png')
# 6. 显示图
plt.show()

# %% [markdown]
# ## 准备数据

# %% [markdown]
# ### 1D数据

# %%
import numpy as np
x = np.linspace(0, 10, 100)
y = np.cos(x)
z = np.sin(x)

# %% [markdown]
# ### 2D数据 或 图像

# %%
from matplotlib.cbook import get_sample_data
import os
data = 2 * np.random.random((10, 10))
data2 = 3 * np.random.random((10, 10))
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
img = np.load(get_sample_data(os.getcwd() + '/axes_grid/bivariate_normal.npy'))

# %% [markdown]
# ## 创建图

# %%
import matplotlib.pyplot as plt
# 魔法函数（Magic Functions）功能是可以内嵌绘图，并且可以省略掉 plt.show()
# %matplotlib inline

# %% [markdown]
# ### 图形（Figure）

# %%
fig = plt.figure()

# %%
fig2 = plt.figure(figsize=plt.figaspect(2.0))

# %% [markdown]
# ### 轴（Axes）

# %% [markdown]
# 所有绘图都是针对 Axes 完成的。 在大多数情况下，子图符合您的需求。子图是网格系统上的轴。

# %%
fig.add_axes()

# %%
ax1 = fig.add_subplot(221)  # 行-列-数字

# %%
ax3 = fig.add_subplot(212)

# %%
fig3, axes = plt.subplots(nrows=2, ncols=2)

# %%
fig4, axes2 = plt.subplots(ncols=3)

# %% [markdown]
# ## 常规绘制

# %% [markdown]
# ### 1D 数据

# %%
fig, ax = plt.subplots()
# 用连接它们的线或标记绘制点
lines = ax.plot(x, y)
# 绘制未连接的点，缩放或着色
ax.scatter(x, y)
# 绘制垂直矩形（恒定宽度）
axes[0, 0].bar([1, 2, 3], [3, 4, 5])
# 绘制horiontal矩形（恒定高度）
axes[1, 0].barh([0.5, 1, 2.5], [0, 1, 2])
# 在轴上绘制一条水平线
axes[1, 1].axhline(0.45)
# 在轴上绘制一条垂直线
axes[0, 1].axvline(0.65)
# 绘制填充的多边形
ax.fill(x, y, color='blue')
# 在 y 值和 0 之间填充
ax.fill_between(x, y, color='yellow')

# %% [markdown]
# ### 2D数据 或 图像

# %%
fig, ax = plt.subplots()
# 彩色贴图或 RGB 数组
im = ax.imshow(img,
               cmap='gist_earth',
               interpolation='nearest',
               vmin=-2,
               vmax=2)

# %%
# 二维数组的伪彩色图
axes2[0].pcolor(data2)
# 二维数组的伪彩色图
axes2[0].pcolormesh(data)
# 绘制轮廓
CS = plt.contour(Y, X, U)
# 绘制填充轮廓
axes2[2].contourf(data)
# 标记等高线图
axes2[2] = ax.clabel(CS)

# %% [markdown]
# ### 向量字段

# %%
# 向轴添加箭头
axes[0, 1].arrow(0, 0, 0.5, 0.5)
# 绘制箭头的 2D 字段
axes[1, 1].quiver(y, z)
# 绘制箭头的 2D 字段
axes[0, 1].streamplot(X, Y, U, V)

# %% [markdown]
# ### 数据分布

# %%
# 绘制直方图
ax1.hist(y)
# 制作一个箱图
ax3.boxplot(y)
# 制作小提琴图
ax3.violinplot(z)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x119cf1240>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x11938ba20>,
#  'cmins': <matplotlib.collections.LineCollection at 0x119cf12b0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x119cf1668>}

# %% [markdown]
# ## 自定义绘图

# %% [markdown]
# ### 颜色，彩条（Color bars）和彩图（Color maps）

# %%
plt.plot(x, x, x, x**2, x, x**3)
ax.plot(x, y, alpha=0.4)
ax.plot(x, y, c='k')
fig.colorbar(im, orientation='horizontal')
im = ax.imshow(img, cmap='seismic')

# %% [markdown]
# ### 标记

# %%
fig, ax = plt.subplots()
ax.scatter(x, y, marker=".")
ax.plot(x, y, marker="o")

# %% [markdown]
# ### 线条样式

# %%
plt.plot(x, y, linewidth=4.0)

# %%
plt.plot(x, y, ls='solid')

# %%
plt.plot(x, y, ls='--')

# %%
plt.plot(x, y, '--', x**2, y**2, '-.')

# %%
plt.setp(lines, color='r', linewidth=4.0)
# Out:
# [None, None]

# %% [markdown]
# ### 文字 & 注释

# %%
ax.text(1,
        -2.1,
        'Example Graph',
        style='italic')
# Out:
# Text(1, -2.1, 'Example Graph')

# %%
ax.annotate("Sine",
            xy=(8, 0),
            xycoords='data',
            xytext=(10.5, 0),
            textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),)
# Out:
# Text(10.5, 0, 'Sine')

# %% [markdown]
# ### 数学

# %%
plt.title(r'$sigma_i=15$', fontsize=20)
# Out:
# Text(0.5, 1.0, '$sigma_i=15$')

# %% [markdown]
# ### 限制，图例 & 布局（Limits, Legends & Layouts）

# %% [markdown]
# #### 限制 & 自动缩放（Limits & Autoscaling）

# %%
ax.margins(x=0.0, y=0.1)
ax.axis('equal')
ax.set(xlim=[0, 10.5], ylim=[-1.5, 1.5])
ax.set_xlim(0, 10.5)
# Out:
# (0, 10.5)

# %% [markdown]
# #### 图例

# %%
# 设置标题和x轴和y轴标签
ax.set(title='An Example Axes',
       ylabel='Y-Axis',
       xlabel='X-Axis')
# Out:
# [Text(3.200000000000003, 0.5, 'Y-Axis'),
#  Text(0.5, 3.1999999999999993, 'X-Axis'),
#  Text(0.5, 1.0, 'An Example Axes')]

# %%
# 不重叠的图元素
ax.legend(loc='best', labels='No overlapping plot elements')

# %% [markdown]
# #### 刻度（Ticks）

# %%
# 手动设置 x-ticks
ax.xaxis.set(ticks=range(1,5),
                 ticklabels=[3,100,-12,"foo"])
# Out:
# [[<matplotlib.axis.XTick at 0x119e291d0>,
# ...
#  [Text(-2.0, 0, '3'),
#   Text(0.0, 0, '100'),
#   Text(2.0, 0, '-12'),
#   Text(4.0, 0, 'foo')]]

# %%
# y-ticks 变长
ax.tick_params(axis='y',
               direction='inout',
               length=10)

# %% [markdown]
# #### 子图间距

# %%
# 调整子图之间的间距
fig3.subplots_adjust(wspace=0.5,
                     hspace=0.3,
                     left=0.125,
                     right=0.9,
                     top=0.9,
                     bottom=0.1)

# %%
# 子图适配图区域
fig.tight_layout()

# %% [markdown]
# #### 坐标轴（Axis Spines）

# %%
# 向下移动底部轴线
ax1.spines['top'].set_visible(False)

# %%
# 使图的顶轴不可见
ax1.spines['bottom'].set_position(('outward', 10))

# %% [markdown]
# ## 保存图

# %% [markdown]
# ### 保存图片（Save figures）

# %%
plt.savefig('bar.png')

# %% [markdown]
# ### 保存透明图（Save transparent figures）

# %%
plt.savefig('bar_trans.png', transparent=True)

# %% [markdown]
# ## 显示图

# %%
plt.show()

# %% [markdown]
# ### 关闭 & 清除

# %%
# 清除轴
plt.cla()

# %%
# 清除整个图
plt.clf()

# %%
# 关闭一个窗口
plt.close()

# %% [markdown]
# ## 示例

# %% [markdown]
# ### 折线图（Line plot）

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.linspace(0, 10, 100)
b = np.exp(-a)
plt.plot(a, b)
plt.show()

# %% [markdown]
# ### 直方图（ Histogram）

# %%
import matplotlib.pyplot as plt
from numpy.random import normal,rand
x = normal(size=200)
plt.hist(x, bins=30)
plt.show()

# %% [markdown]
# ### 散点图（Scatter plot）

# %%
import matplotlib.pyplot as plt
from numpy.random import rand
a = rand(100)
b = rand(100)
plt.scatter(a, b)
plt.show()

# %% [markdown]
# ### 3D 图（3D plot）

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)
plt.show()
